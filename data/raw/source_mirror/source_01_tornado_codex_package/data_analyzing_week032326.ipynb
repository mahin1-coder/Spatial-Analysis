# %% [markdown]
# Code analyzing week of 03/23/2026
#
# Take-away from last meeting:
#
# 1. 6 clusters might not be sufficient (K-means)
#
# 2. Unsupervised might not work (K-means) → try supervised
#
# 3. You’re only looking horizontally → need vertical layers.
#
#     Right now you treat image like RGB (flat), each pixel has 6 bands (layers) You’re ignoring the depth (feature dimension)
#
# 4. Map subtraction
#
#     Map 1: From satellite, what you currently see (after tornado), including: roads, trees, buildings, tornado damage
#
#     Map 2: Reference map, normal world (Google Maps / OSM), including: roads, buildings, trees (maybe)
#
#     Tornado paths = Map 1 - Map 2
